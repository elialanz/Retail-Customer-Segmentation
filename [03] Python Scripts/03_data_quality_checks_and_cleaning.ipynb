# %% [markdown]
# # Data Consistency Checks [4.5]

# %% [markdown]
# ## Lesson Exercise

# %%
import pandas as pd
import numpy as np
import os

# %%
# Assigning Path
path = r'/Users/elia/Desktop/DATA ANALYST/CAREER FOUNDRY/B - Data Analytics Immersion/4 - PYTHON FOR ANALYSTS/09-2025 Instacart Basket Analysis'

# %%
# Import Dataframe (Orders.csv)
df_ords = pd.read_csv(os.path.join(path, '02 - Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
# Import Dataframe (Products.csv)
df_prods = pd.read_csv(os.path.join(path, '02 - Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
# Get Basic Statistics with describe function
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
# Create a Dataframe

df_test = pd.DataFrame()

# %%
# Create a mixed type column

df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types

for col in df_test.columns.tolist():
  weird = (df_test[[col]].map(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_nan
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_nan['product_name'].fillna(mean value, inplace=True)
# Out:
#   Cell In[15], line 1
#     df_nan['product_name'].fillna(mean value, inplace=True)
#                                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 - Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # Data Consistency Checks [4.5]

# %% [markdown]
# ## Task

# %% [markdown]
# #### Step 2 - Run the df.describe() function on your df_ords dataframe. Using your new knowledge about how to interpret the output of this function, share in a markdown cell whether anything about the data looks off or should be investigated further.

# %%
df_ords.describe().round(2)
# Out:
#          order_id     user_id  order_number   order_dow  order_hour_of_day  \
# count  3421083.00  3421083.00    3421083.00  3421083.00         3421083.00
# mean   1710542.00   102978.21         17.15        2.78              13.45
# std     987581.74    59533.72         17.73        2.05               4.23
# min          1.00        1.00          1.00        0.00               0.00
# 25%     855271.50    51394.00          5.00        1.00              10.00
# 50%    1710542.00   102689.00         11.00        3.00              13.00
# 75%    2565812.50   154385.00         23.00        5.00              16.00
# max    3421083.00   206209.00        100.00        6.00              23.00
#
#        days_since_prior_order
# count              3214874.00
# mean                    11.11
# std                      9.21
# min                      0.00
# 25%                      4.00
# 50%                      7.00
# 75%                     15.00
# max                     30.00

# %% [markdown]
# ##### There is few things that looks a bit off for me, one is the "order_dow", which seems like having a min of 0 instead of 1 and a max 6 instead of 7, another one is the "order_number" column max which seems a little low compared for example to the max of "order_id".

# %% [markdown]
# #### ---

# %% [markdown]
# #### Step 3 - Check for mixed-type data in your df_ords dataframe.

# %%
# Check for mixed types

for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %%
df_ords
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %% [markdown]
# ##### I have created a loop that will print the column name if there is inconsistent data types in that column.
# ##### No mixed-type data was detected in df_ords. All columns appear to have consistent data types, which is a good sign for further analysis.

# %% [markdown]
# #### ---

# %% [markdown]
# #### Step 5 - Run a check for missing values in your df_ords dataframe.
# #### In a markdown cell, report your findings and propose an explanation for any missing values you find.

# %%
# The isnull sum function will highlight the columns with missing values and the relative number.

df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# ##### The only missing values are found in the "days_since_prior_order" column, which is around 6% of the total rows. I think this could be because that is the customer first order ever, and therefore there isnt such of a value because simply the customer didnt order previously, so in that case replace with a "0" or "1" could be misleading, i think probably is just better to not edit it.

# %%
# I will create a "nan" version of the dataframe, with this approach i can focus on looking at this columns,
# and understand the reason behind the missing values

df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_ords_nan.head(25)
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     2539329        1    prior             1          2                  8
# 11    2168274        2    prior             1          2                 11
# 26    1374495        3    prior             1          1                 14
# 39    3343014        4    prior             1          6                 11
# 45    2717275        5    prior             1          3                 12
# 50    2086598        6    prior             1          5                 18
# 54    2565571        7    prior             1          3                  9
# 75     600894        8    prior             1          6                  0
# 79     280530        9    prior             1          1                 17
# 83    1224907       10    prior             1          2                 14
# 89    2411567       11    prior             1          0                 11
# ...

# %% [markdown]
# #### Step 7 - Run a check for duplicate values in your df_ords data.
# #### In a markdown cell, report your findings and propose an explanation for any duplicate values you find.

# %%
# First i want to know the rows and columns with shape function

df_ords.shape
# Out:
# (3421083, 7)

# %%
# Then i want to have a general look of the dataframe

df_ords
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# Here i will create a "clean" version focusing on the order_id column, which i think it will be the most important to check for duplicates.

df_ords_clean = df_ords[df_ords['order_id'].isnull() == False]

# %%
df_ords_clean
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ords_clean.shape
# Out:
# (3421083, 7)

# %%
# Here i will create another version of the dataframe to check for duplicates.

df_ords_dups = df_ords_clean[df_ords_clean.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_ords_clean_no_dups = df_ords_clean.drop_duplicates()

# %%
# Using the shape function on the "no_dups" version is going to show me that there isnt any duplicates,
# considering the shape before and after have equal numbers.

df_ords_clean_no_dups.shape
# Out:
# (3421083, 7)

# %% [markdown]
# #### Step 9 - Export your final, cleaned df_prods and df_ords data as “.csv” files in your “Prepared Data” folder and give them appropriate, succinct names.

# %%
df_ords_clean_no_dups.to_csv(os.path.join(path, '02 - Data', 'Prepared Data', 'orders_checked.csv'))

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 - Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_ords_clean_no_dups.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df_prods_clean_no_dups.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      9.993282
# std    14340.705287     38.315784       5.850779    453.615536
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000  99999.000000
